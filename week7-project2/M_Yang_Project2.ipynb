# %% [markdown]
# This project are done by Xiaojia He, Manling Yang, Yalin Yan

# %%
import csv 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# be sure to update the path below to reflect your own environment!! 
# also be sure that the code is properly indented after you paste it! 

df = pd.read_csv(r"C:\Users\13750\Desktop\yu\DAV5400 Analytics Programming\Assignment\week7-project2\index.csv")
df
# Out:
#             County                               Agency  Year  \
# 0         Dutchess                       Red Hook Vg PD  2004
# 1          Steuben               Steuben County Sheriff  2017
# 2           Nassau                       Lynbrook Vg PD  2015
# 3        Schoharie             Schoharie PCT (NYC-DEPP)  2003
# 4       Chautauqua            Chautauqua County Sheriff  2016
# 5       Chautauqua                         County Total  2016
# 6             Erie                  Erie County Sheriff  2015
# 7          Suffolk                    Suffolk County PD  2012
# 8         Franklin         Franklin County State Police  2015
# 9      Westchester        Croton-Kensico PCT (NYC-DEPP)  2011
# 10         Suffolk                 East Hampton Town PD  2014
# 11     St Lawrence                      Norfolk Town PD  2015
# 12          Orange                         County Total  2016
# 13          Otsego                      Oneonta City PD  2017
# ...

# %% [markdown]
# # Introduction

# %% [markdown]
# This data collects the crime information from New York State police and departments. It reported seven crimes classified as Index offenses which are most commonly used to gauge overall crime volume. These include the violent crimes(murder, non-negligent manslaughter, forcible rape, robbery, and aggravated assault), and the property crimes(burglary, larceny, and motor vehicle theft).The counts represent only crimes reported to the police but not total crimes that occurred.

# %% [markdown]
# ## Research Question:
# ### Which county is the most dangerous, and has the highest index total of crime?

# %% [markdown]
# # Data Summary
# （Q1:Explain where you acquired your data from; Q2: how many use cases your data set provides; Q3: how many attributes are in each use case; Q4: what the data types are for each of the attributes; etc.）
# Q1： I acquired this data from kaggle website. It has many use cases so i will only focus on those which are more important and useful:
# 1. Which county is the most dangerous, and has the highest index total of crime? This use case will use two attributes. county is a regular categorical, and index total is discrete.
# 2. which crime is most common in all the counties? This use case will use the seven crime attributes. All of they are discrete.
# 3. In which year the crime rate was lowest? This use case will use the year and index total attributes. Year is regular categorical, and index total is discrete.
# Q2: There are 19324 uses cases that my data set provides.
# Q3: There are 15 attributes in each use case, including Country, Agency, Year, Months Reported, Index Total, Violent Total, Murder, Rape, Robbery, Aggravated Assault, Property Total, Burglary, Larceny, Motor Vehicle Theft, and Region.
# Q4: data types for each abbribuates:
#     County:
#     Agency:
#     Year:
#     Months Reported:
#     Index Total:
#     Violent Total:
#     Murder:
#     Rape:
#     Robbery:
#     Aggravated Assault:
#     Property Total:
#     Burglary:
#     Larceny:
#     Motor Vehicle Theft:
#     Region:

# %% [markdown]
# # Exploratory Data Analysis (EDA):

# %%
#summary statistics for each attribute

# %%
# 1. For Index county and Total attributes, use bar chart to see the number of index total in different counties.

plt.bar(df['County'], df['Index Total'])
# Out:
# <BarContainer object of 19324 artists>

# %%
# 2. For the Index total attribute, we can make a plot to see the distribution 

df['Index Total'].plot()

# %% [markdown]
# #From the chart we can see that the chart is fluctured, and the biggest index total is about 50000, and lots of data show zero crime which is great.

# %%
# 2. For these seven attributes of crime, I can use figuer histogram to show their Frequencies of occurrence.

fig,axes=plt.subplots(3,3,figsize=(15,10))

murder = axes[0,0].hist(df['Murder'])
axes[0,0].set_title('murder')

rape = axes[0,1].hist(df['Rape'])
axes[0,1].set_title('rape')

rape = axes[0,2].hist(df['Robbery'])
axes[0,2].set_title('robbery')

rape = axes[1,0].hist(df['Aggravated Assault'])
axes[1,0].set_title('aggravated assault')

rape = axes[1,1].hist(df['Burglary'])
axes[1,1].set_title('burglary')

rape = axes[1,2].hist(df['Larceny'])
axes[1,2].set_title('larceny')

rape = axes[2,0].hist(df['Motor Vehicle Theft'])
axes[2,0].set_title('motor vehicle theft')

fig.suptitle('This is a figure about the consequency of seven crimes', fontsize=16)
# Out:
# Text(0.5, 0.98, 'This is a figure about the consequency of seven crimes')

# %% [markdown]
# Text(0.5, 0.98, 'This is a figure about the consequency of seven crimes')
