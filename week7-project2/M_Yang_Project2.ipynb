# %% [markdown]
# This project are done by Xiaojia He, Manling Yang, Yalin Yan

# %% [markdown]
# 1. define the csv, numpy, panda, seaborn, and matplotlib first
# 2. read the pathway to load the dataset
# 3. remove the unmeaningful columns from the dataset
# 4. print the results

# %%
# import csv
# define numpy as np
# define panda as pd
# define seaborn as sns
# define matplotlib as plt
# read the data file from own pathway
# remove the unmeaningful column，Unnamed: 11， Unnamed: 12 by drop function
# print the result as df
import csv 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df0 = pd.read_csv(r"C:\Users\13750\Desktop\yu\DAV5400 Analytics Programming\Assignment\week7-project2\index.csv")
df = df0.drop(columns = ['Unnamed: 11','Unnamed: 12'])
df
# Out:
#             County                        Agency  Year  Index Total  Murder  \
# 0          Steuben        Steuben County Sheriff  2017        115.0     0.0
# 1           Otsego               Oneonta City PD  2017        261.0     1.0
# 2          Ontario           Canandaigua City PD  2017        242.0     1.0
# 3         Onondaga       Onondaga County Park PD  2017         17.0     0.0
# 4          Suffolk             Suffolk County PD  2017      18478.0    22.0
# 5       Chautauqua                  County Total  2017       2786.0     3.0
# 6          Ontario                  Phelps Vg PD  2017          2.0     0.0
# 7           Broome         Broome County Sheriff  2017        552.0     0.0
# 8        Jefferson      Jefferson County Park PD  2017         12.0     0.0
# 9         Chenango                  County Total  2017        685.0     3.0
# 10        Franklin                  Malone Vg PD  2017        163.0     0.0
# 11        Columbia                Philmont Vg PD  2017          6.0     0.0
# 12        Dutchess       Dutchess County Sheriff  2017        477.0     1.0
# 13          Oneida         Oneida County Sheriff  2017        408.0     0.0
# 14     Westchester            Greenburgh Town PD  2017        664.0     1.0
# 15          Otsego                  County Total  2017        732.0     4.0
# 16        Rockland                  County Total  2017       3404.0     1.0
# 17       Jefferson      Jefferson County Sheriff  2017        325.0     0.0
# 18         Wyoming                   Perry Vg PD  2017         63.0     0.0
# 19          Cayuga                  County Total  2017       1341.0     1.0
# 20      Washington            Hudson Falls Vg PD  2017         71.0     1.0
# 21          Seneca         Seneca County Sheriff  2017         32.0     0.0
# 22       Jefferson                  County Total  2017       2253.0     4.0
# 23         Madison                Oneida City PD  2017        410.0     1.0
# 24      Montgomery                  County Total  2017        938.0     1.0
# 25        New York                  County Total  2017      47146.0    46.0
# 26        Hamilton                  County Total  2017         36.0     0.0
# 27       Jefferson                Carthage Vg PD  2017         64.0     0.0
# 28          Otsego         Otsego County Sheriff  2017         80.0     3.0
# 29           Wayne          Wayne County Sheriff  2017        529.0     2.0
# ...            ...                           ...   ...          ...     ...
# 19259       Oneida          New York Mills Vg PD  1990         85.0     0.0
# 19260      Suffolk              Amityville Vg PD  1990        350.0     0.0
# 19261   Livingston     Livingston County (RR-RC)  1990          3.0     0.0
# 19262   Washington               Granville Vg PD  1990        118.0     0.0
# 19263       Fulton             Johnstown City PD  1990        610.0     0.0
# 19264     Onondaga           Baldwinsville Vg PD  1990        198.0     0.0
# 19265  Westchester            New Castle Town PD  1990        217.0     0.0
# 19266      Madison        Madison County Sheriff  1990        118.0     0.0
# 19267      Clinton        Clinton County Park PD  1990         12.0     0.0
# 19268     Allegany                  Cuba Town PD  1990         61.0     0.0
# 19264    4.0      1.0                 6.0      24.0    158.0
# 19265    0.0      0.0                12.0      43.0    148.0
# 19266    0.0      1.0                 0.0      52.0     61.0
# 19267    0.0      0.0                 1.0       2.0      9.0
# 19268    0.0      0.0                 9.0      15.0     35.0
# 19269    0.0      2.0                19.0      34.0    206.0
# 19270    5.0      1.0                21.0     272.0    226.0
# 19271    0.0      0.0                10.0      46.0     33.0
# 19272    3.0      1.0                65.0     241.0    268.0
# 19273   21.0     46.0                25.0     349.0   2336.0
# 19274    0.0      0.0                 5.0      11.0     93.0
# 19275    0.0      4.0                13.0      72.0    207.0
# 19276   15.0    136.0                50.0     871.0   2020.0
# 19277    0.0      0.0                 0.0      14.0     14.0
# 19278   15.0     10.0               157.0     756.0   2139.0
# 19279    0.0      2.0                 0.0     125.0    587.0
# 19280    0.0      0.0                 1.0       2.0     12.0
# 19281   36.0    129.0                76.0    1163.0   1700.0
# 19282    9.0      8.0                43.0     513.0    475.0
# 19283    4.0     17.0                53.0     365.0   1460.0
# 19284    0.0      1.0                 1.0      12.0     19.0
# 19285   42.0    309.0               743.0    1645.0   5689.0
# 19286    0.0      1.0                 0.0       8.0      0.0
# 19287    6.0     10.0               140.0     183.0    729.0
# 19288    0.0      0.0                 4.0      11.0     33.0
#
#        Motor Vehicle Theft
# 0                      3.0
# 1                      1.0
# 2                      5.0
# 3                      0.0
# 4                   1008.0
# 5                     82.0
# 6                      0.0
# 7                     18.0
# 8                      0.0
# 9                     10.0
# 10                     5.0
# 11                     0.0
# 12                    15.0
# 13                    14.0
# 14                    24.0
# 15                    15.0
# 16                    94.0
# 17                     8.0
# 18                     2.0
# 19                    25.0
# 20                     1.0
# 21                     0.0
# 22                    47.0
# 23                     4.0
# 24                    23.0
# 25                   638.0
# 26                     3.0
# 27                     2.0
# 28                     6.0
# 29                    18.0
# ...                    ...
# 19259                  3.0
# 19260                 67.0
# 19261                  0.0
# 19262                  1.0
# 19263                 19.0
# 19264                  5.0
# 19265                 14.0
# 19266                  4.0
# 19267                  0.0
# 19268                  2.0
# 19269                 31.0
# 19270                 11.0
# 19271                  7.0
# 19272                 35.0
# 19273                111.0
# 19274                  7.0
# 19275                 13.0
# 19276                263.0
# 19277                  4.0
# 19278                 53.0
# 19279                 25.0
# 19280                  0.0
# 19281                257.0
# 19282                 24.0
# 19283                 53.0
# 19284                  1.0
# 19285                519.0
# 19286                  0.0
# 19287                 33.0
# 19288                  1.0
#
# [19289 rows x 11 columns]

# %% [markdown]
# # Introduction

# %% [markdown]
#      The data set contains the New York State criminal information from 1990 to 2017. It is made by the  Division of Criminal Justice Services (DCJS).  It reported seven crimes classified as Index offenses, which are most commonly used to gauge overall crime volume. The data include violent crimes (murder, non-negligent manslaughter, forcible rape, robbery, and aggravated assault) and property crimes  (burglary, larceny, and motor vehicle theft). The counts represent only crimes reported to the police but not total crimes that occurred.

# %% [markdown]
# ## Research Question:
# ### Which county is the most dangerous basic on the index total of crime ？

# %% [markdown]
# # Data Summary
#
#
# Q1. I acquired this data from kaggle website.(https://www.kaggle.com/new-york-state/new-york-state-index-crimes) It has many use cases so i will only focus on those which are more important and useful:
# 1. Which county of New York State is the most dangerous basic on the highest index total of crime? This use case will use two attributes. county is a regular categorical, and index total is discrete.
# 2. which crime is most common in all the counties? This use case will use the seven crime attributes. All of they are discrete.
# 3. In which year the crime rate was lowest? This use case will use the year and index total attributes. Year is regular categorical, and index total is discrete.
#
# Q2.  There are 19324 uses cases that my data set provides.
#
# Q3. There are 11 attributes in each use case, including Country, Agency, Year, Index Total, Murder, Rape, Robbery, Aggravated Assault, Burglary, Larceny, and Motor Vehicle Theft.
#
# Q4.  data types for each abbribuates:
# 1) County: regular categorial
# 2) Agency: regular categorial
# 3) Year: ordinal/categorial
# 4) Index Total: discrete/numerical
# 5) Murder: discrete/numerical
# 6) Rape: discrete/numerical
# 7) Robbery: discrete/numerical
# 8) Aggravated Assault: discrete/numerical
# 9) Burglary: discrete/numerical
# 10) Larceny: discrete/numerical
# 11) Motor Vehicle Theft: discrete/numerical

# %% [markdown]
# # Exploratory Data Analysis (EDA):

# %% [markdown]
# 1. create the summary statistic for each attribute, including county, Agency,Year,Index,Total, Murder, Rape, Robbery,Aggravated Assault, Burglary, Larceny, and Motor Vehicle Theft.
# 2. create the charts for each attribute by Matplotlib.
# 3. create the charts for each attribute by Seaborn.

# %%
# use groupby function to get descriptive statistics for the County column with sum of each other columns
#print the result
county1 = df.groupby('County').sum()
county1
# Out:
#                 Year  Index Total  Murder     Rape   Robbery  \
# County
# Albany        949316     693132.0   520.0   4516.0   25414.0
# Allegany      669340      51462.0    36.0    840.0     146.0
# Bronx          56098    1461565.0  6011.0  11290.0  212977.0
# Broome        657016     366954.0   300.0   3378.0    6114.0
# Cattaraugus   617034     116828.0    76.0   1260.0     814.0
# Cayuga        456728     107000.0    72.0   1294.0    1198.0
# Chautauqua    727173     231798.0   142.0   2104.0    3404.0
# Chemung       470634     159984.0   138.0   1276.0    2290.0
# Chenango      588947      62466.0    48.0    836.0     254.0
# Clinton       420554      96440.0    70.0   1252.0     396.0
# Columbia      588900      75666.0    52.0    638.0     964.0
# Cortland      384594      83948.0    32.0    910.0     646.0
# Delaware      544795      49094.0    40.0    616.0     218.0
# Dutchess      969616     359624.0   438.0   2800.0   11684.0
# Erie         1534289    2100360.0  3256.0  15890.0  116422.0
# Essex         316602      34280.0    36.0    526.0     104.0
# Franklin      308566      55764.0    48.0    940.0     260.0
# Fulton        338617      93316.0    34.0    884.0     662.0
# Genesee       368547      87310.0    50.0    998.0     886.0
# Greene        532989      56434.0    66.0    608.0     380.0
# Hamilton      234417       4920.0     2.0     44.0       4.0
# Herkimer      616974      76006.0    36.0    888.0     542.0
# Jefferson     853447     144852.0   130.0   2352.0    1398.0
# Kings          56098    2531196.0  8423.0  17391.0  379651.0
# Lewis         244476      19052.0    18.0    338.0      62.0
# Livingston    619048      82192.0    40.0    768.0     346.0
# Madison       592943      77942.0    50.0    884.0     452.0
# Monroe        869425    1714978.0  2768.0  10374.0   71508.0
# Montgomery    422704      56670.0    40.0    474.0     558.0
# Nassau       1412264    1428036.0  1448.0   5458.0   66984.0
# ...              ...          ...     ...      ...       ...
# Livingston               4030.0   11092.0    64254.0               1662.0
# Madison                  2766.0   15778.0    56476.0               1536.0
# Monroe                  65800.0  290340.0  1131430.0             142758.0
# Montgomery               3646.0   11106.0    39354.0               1492.0
# Nassau                  72808.0  194080.0   901078.0             186180.0
# ...                         ...       ...        ...                  ...
# Oneida                  19648.0   75862.0   257748.0              14748.0
# Onondaga                58006.0  182922.0   572764.0              49214.0
# Ontario                  4088.0   21178.0    88654.0               3110.0
# Orange                  38436.0   77778.0   342960.0              19280.0
# Orleans                  3930.0   10382.0    33852.0               1656.0
# Oswego                   5778.0   35964.0   114378.0               4840.0
# Otsego                   4438.0   14446.0    41992.0               1268.0
# Putnam                   2956.0   13592.0    42868.0               2940.0
# Queens                 198453.0  299836.0   838661.0             413807.0
# Rensselaer              17048.0   59032.0   171798.0              12204.0
# Richmond                34067.0   38351.0   136814.0              49071.0
# Rockland                21422.0   43402.0   230038.0              14380.0
# Saratoga                12714.0   34470.0   135336.0               5352.0
# Schenectady             20712.0   63182.0   201636.0              15448.0
# Schoharie                1518.0    7578.0    19810.0                756.0
# Schuyler                  880.0    3526.0    11898.0                596.0
# Seneca                   2168.0    6218.0    28750.0                918.0
# St Lawrence              8254.0   29416.0   105344.0               3588.0
# Steuben                  7394.0   23050.0    86950.0               2824.0
# Suffolk                 88374.0  341456.0  1463822.0             187844.0
# Sullivan                11248.0   36466.0    67304.0               3744.0
# Tioga                    2734.0    8674.0    24932.0               1364.0
# Tompkins                 4236.0   29014.0   129978.0               3304.0
# Ulster                  19352.0   42038.0   151492.0               8220.0
# Warren                   6698.0   15456.0    74882.0               1920.0
# Washington               6674.0   12170.0    36186.0               1538.0
# Wayne                    6066.0   24764.0    81520.0               3532.0
# Westchester             80820.0  172826.0   753048.0             131494.0
# Wyoming                  4738.0   12876.0    26876.0               1384.0
# Yates                    1274.0    5278.0    15962.0                410.0
#
# [62 rows x 9 columns]

# %% [markdown]
# According to the datafarm, there are 62 Counties in the reports.In addition, the other columns shows the same number for each County. Those numbers are the sum of each County in the reports. The year information is not meaningful.

# %%
#define numpy and matplotlib
#consider the coulumns are same numbers except the Index Total columns,drop other unmeaningful columns. 
#plot a bar chart to show the total index crimes for each County reports by matplotlib
import numpy as np
import matplotlib.pyplot as plt
county2 = county1.drop(columns = ['Year','Murder','Rape','Robbery','Aggravated Assault','Burglary','Larceny','Motor Vehicle Theft'])
county2['Index Total'].plot(kind='bar')

# %% [markdown]
# There are five counties reports more than 2,000,000 crimes during 1990 to 2017.

# %%
#use the seaborn function to create the scatter plot of total crimes for each county during 1990 to 2017.
sns.swarmplot(x = county2['Index Total'])

# %% [markdown]
# Depend on the scatter plot, most of counties in New York State reports the total crimes less than 500,000 from 1990 to 2017.

# %%
# use groupby function to get descriptive statistics for the Agency column with sum of each other columns
#print the result
Agency1 = df.groupby('Agency').sum()
Agency1
# Out:
#                                      Year  Index Total  Murder    Rape  \
# Agency
# Adams Vg PD                         56098        436.0     0.0     1.0
# Addison Vg PD                       56098       1076.0     1.0     6.0
# Afton Vg PD                         56098        523.0     0.0     5.0
# Youngstown Vg PD                    32152        116.0     0.0     1.0
#
#                                     Robbery  Aggravated Assault  Burglary  \
# Agency
# Adams Vg PD                             1.0                23.0     104.0
# Addison Vg PD                           6.0               154.0     174.0
# Afton Vg PD                             5.0                40.0     111.0
# Akron Vg PD                             7.0               113.0     112.0
# Albany City PD                      10667.0             17563.0   37744.0
# Albany County (RR-CSX)                  0.0                 0.0       1.0
# Albany County (RR-D and H)              0.0                 0.0      13.0
# Albany County (RR-RC)                   0.0                 0.0     173.0
# Albany County Park PD                   0.0                 1.0       9.0
# Albany County Park PD Headquarters      0.0                 0.0       0.0
# Albany County Sheriff                  23.0               574.0     876.0
# Albany County State Police             89.0               386.0    1230.0
# Albion Vg PD                          139.0               614.0    1243.0
# Alexandria Bay Vg PD                    5.0                69.0     189.0
# Alfred Vg PD                           14.0               182.0     440.0
# Allegany County (RR-RC)                 0.0                 0.0       0.0
# Allegany County Park PD                 0.0                 0.0       0.0
# Allegany County Sheriff                 1.0                56.0      23.0
# Allegany County State Police           32.0              1008.0    4186.0
# Allegany Vg PD                          9.0               227.0     180.0
# Altamont Vg PD                          6.0                25.0      37.0
# Amherst Town PD                      1233.0              2118.0    6660.0
# Amityville Vg PD                      250.0               148.0     832.0
# Amsterdam City PD                     184.0               908.0    2848.0
# Andover Vg PD                           0.0                18.0      19.0
# Angelica Vg PD                          0.0                37.0      92.0
# Angola Vg PD                            4.0                45.0     161.0
# Arcade Vg PD                            2.0               120.0     243.0
# Ardsley Vg PD                          49.0               101.0     287.0
# Asharoken Vg PD                         0.0                 2.0      10.0
# ...                                     ...                 ...       ...
# Westchester County (RR-CSX)             0.0                 0.0       1.0
# Westchester County (RR-MN)            119.0               183.0     120.0
# Westchester County (RR-RC)              0.0                 0.0       0.0
# Westchester County MTA                139.0                88.0      42.0
# Westchester County Park PD              3.0                19.0      24.0
# Westchester County State Police       255.0              1940.0    2862.0
# Westfield Vg PD                         6.0               105.0     256.0
# Westhampton Beach Vg PD                20.0               177.0     485.0
# Wheatland Town PD                       2.0                13.0      74.0
# White Plains City PD                 1551.0              2513.0    3182.0
# Whitehall Vg PD                        13.0               254.0     191.0
# Whitesboro Vg PD                       17.0               187.0     312.0
# Whitestown Town PD                      7.0                64.0     344.0
# Windham Town PD                         0.0                37.0     259.0
# Windsor Town PD                         0.0                 0.0       2.0
# Wolcott Vg PD                           0.0                 6.0      14.0
# Woodbury Town PD                       52.0               167.0     505.0
# Woodridge Vg PD                        10.0                98.0     272.0
# Woodstock Town PD                      20.0               183.0     773.0
# Wyoming County (RR-RC)                  0.0                 0.0       0.0
# Wyoming County Park PD                  0.0                 4.0       9.0
# Wyoming County Sheriff                 60.0               987.0    4420.0
# Wyoming County State Police            10.0               821.0     519.0
# Yates County Park PD                    0.0                 0.0       0.0
# Yates County Sheriff                   14.0               464.0    1919.0
# Yates County State Police               3.0                91.0     265.0
# Yonkers City PD                     14974.0             12643.0   26512.0
# Yorktown Town PD                      148.0               421.0    1786.0
# Yorkville Vg PD                        28.0               129.0     339.0
# Youngstown Vg PD                        0.0                 4.0      23.0
#
#                                      Larceny  Motor Vehicle Theft
# Agency
# Adams Vg PD                            296.0                 11.0
# Addison Vg PD                          709.0                 26.0
# Afton Vg PD                            349.0                 13.0
# Akron Vg PD                            517.0                 30.0
# Albany City PD                      100526.0               9889.0
# Albany County (RR-CSX)                  61.0                  0.0
# Albany County (RR-D and H)              49.0                  0.0
# Albany County (RR-RC)                  652.0                  0.0
# Albany County Park PD                  120.0                  0.0
# Albany County Park PD Headquarters       0.0                  0.0
# Albany County Sheriff                 2240.0                177.0
# Albany County State Police            7162.0                291.0
# Albion Vg PD                          5432.0                198.0
# Alexandria Bay Vg PD                   531.0                 26.0
# Alfred Vg PD                          1719.0                 49.0
# Allegany County (RR-RC)                  1.0                  0.0
# Allegany County Park PD                  0.0                  0.0
# Allegany County Sheriff                 59.0                  8.0
# Allegany County State Police          5531.0                275.0
# Allegany Vg PD                        1630.0                  9.0
# Altamont Vg PD                         189.0                 11.0
# Amherst Town PD                      53264.0               3255.0
# Amityville Vg PD                      4788.0                458.0
# Amsterdam City PD                     7011.0                245.0
# Andover Vg PD                           64.0                  5.0
# Angelica Vg PD                         158.0                  7.0
# Angola Vg PD                           746.0                 26.0
# Arcade Vg PD                          1259.0                 37.0
# Ardsley Vg PD                         1135.0                 86.0
# Asharoken Vg PD                        108.0                  5.0
# ...                                      ...                  ...
# Westchester County (RR-CSX)              6.0                  0.0
# Westchester County (RR-MN)             948.0                  5.0
# Westchester County (RR-RC)               2.0                  0.0
# Westchester County MTA                1555.0                 53.0
# Westchester County Park PD             388.0                  8.0
# Westchester County State Police      10173.0                966.0
# Westfield Vg PD                       1710.0                 60.0
# Westhampton Beach Vg PD               1591.0                123.0
# Wheatland Town PD                      343.0                 31.0
# White Plains City PD                 43564.0               3037.0
# Whitehall Vg PD                        791.0                 46.0
# Whitesboro Vg PD                      1178.0                 64.0
# Whitestown Town PD                    1541.0                 67.0
# Windham Town PD                        585.0                 20.0
# Windsor Town PD                          1.0                  0.0
# Wolcott Vg PD                           67.0                  1.0
# Woodbury Town PD                      8959.0                246.0
# Woodridge Vg PD                        341.0                 27.0
# Woodstock Town PD                     1959.0                 91.0
# Wyoming County (RR-RC)                   7.0                  0.0
# Wyoming County Park PD                 129.0                  0.0
# Wyoming County Sheriff                5059.0                386.0
# Wyoming County State Police            867.0                 92.0
# Yates County Park PD                    14.0                  0.0
# Yates County Sheriff                  4081.0                120.0
# Yates County State Police              575.0                 31.0
# Yonkers City PD                      78322.0              26228.0
# Yorktown Town PD                     13386.0                386.0
# Yorkville Vg PD                       1069.0                 79.0
# Youngstown Vg PD                        86.0                  2.0
#
# [833 rows x 9 columns]

# %% [markdown]
# According to the datafarm, there are 833 police department in New York State. The sum of year is unmeaningful information.

# %%
#use the matplotlib function to crete the bar chart in 
Agency1['Index Total'].plot(kind='bar')

# %% [markdown]
# most of Anency reports the total numbers of crimes are closed from 1990 to 2017.

# %%
# remove the columns I do not need
# use seaborn function to create the scatter plot
Agency2 = Agency1.drop(columns = ['Year','County','Murder','Rape','Robbery','Aggravated Assault','Burglary','Larceny','Motor Vehicle Theft','Unnamed: 11','Unnamed: 12'])
sns.swarmplot(x = Agency2['Index Total'])

# %% [markdown]
# Most of agencies reports the total numbers of crimes, from 1990 to 2017, are closed but one of them is really high, around 1750.

# %%
#get descriptive statistics for the year column by describe function
df['Year'].describe()
# Out:
# count    19289.000000
# mean      2003.288247
# std          8.021291
# min       1990.000000
# 25%       1996.000000
# 50%       2003.000000
# 75%       2010.000000
# max       2017.000000
# Name: Year, dtype: float64

# %% [markdown]
# According to the table, we can know the year range is from 1990 to 2017, the other information is not meaningful.

# %%
# 2. For the Year attribute, because it's just a regular categorical, we need to combine the index total attribute to make
# the plot which could show the total crimes in different year. 
# At first, we need to groupby the years and sum the their index totals and create a neew datafram to store the data, then 
#make a plot.
year_df = df.groupby('Year').sum()
year_df
# Out:
#       Index Total  Murder     Rape   Robbery  Aggravated Assault  Burglary  \
# Year
# 1990    1563360.0  2967.0   7570.0  124174.0            114505.0  294642.0
# 1991    1571991.0  2960.0   7270.0  126091.0            113311.0  295831.0
# 1992    1489357.0  2769.0   7437.0  119955.0            110495.0  281319.0
# 1993    1420191.0  2826.0   7134.0  113824.0            107828.0  262917.0
# 1994    1307005.0  2399.0   6729.0  100502.0            103763.0  239324.0
# 1995    1212048.0  1924.0   6111.0   85777.0             95448.0  219659.0
# 1996    1118168.0  1677.0   5987.0   74007.0             83442.0  198524.0
# 1997    1061738.0  1403.0   6012.0   67557.0             81979.0  184007.0
# 1998     974803.0  1213.0   5828.0   59066.0             79926.0  161753.0
# 1999     906157.0  1159.0   5170.0   54028.0             74328.0  142549.0
# 2000     882351.0  1241.0   5061.0   50617.0             76316.0  133041.0
# 2001     850745.0  1293.0   5363.0   47228.0             74795.0  126700.0
# 2002     827189.0  1223.0   5859.0   46663.0             71611.0  122888.0
# 2003     801937.0  1237.0   5931.0   45567.0             66531.0  122541.0
# 2004     774404.0  1210.0   5694.0   42327.0             63613.0  113758.0
# 2005     761666.0  1209.0   5818.0   45286.0             64112.0  112394.0
# 2006     750212.0  1258.0   5259.0   45251.0             63778.0  114837.0
# 2007     722049.0  1120.0   4973.0   40285.0             62805.0  108754.0
# 2008     730963.0  1149.0   4684.0   41300.0             59319.0  111161.0
# 2009     711583.0  1097.0   4298.0   37529.0             60379.0  106574.0
# 2010     712756.0  1196.0   4496.0   37202.0             60289.0  111464.0
# 2011     706152.0  1025.0   4454.0   36929.0             61311.0  112019.0
# 2012     708977.0   957.0   4500.0   36909.0             63249.0  109525.0
# 2013     671001.0   955.0   4120.0   35188.0             60313.0   95740.0
# 2014     635149.0   899.0   4008.0   31407.0             58976.0   85410.0
# 2015     602884.0   888.0  10054.0   30830.0             58452.0   74038.0
# 2016     581308.0   925.0  10114.0   29022.0             59045.0   67393.0
# 2017     551772.0   802.0  10351.0   26057.0             57487.0   58350.0
#
#        Larceny  Motor Vehicle Theft  Unnamed: 11  Unnamed: 12
# Year
# 1990  793156.0             226346.0          0.0          0.0
# 1991  803873.0             222655.0          0.0          0.0
# 1992  757826.0             209556.0          0.0          0.0
# 1993  734463.0             191199.0          0.0          0.0
# 1994  692367.0             161921.0          0.0          0.0
# 1995  670640.0             132489.0          0.0          0.0
# 1996  635290.0             119241.0          0.0          0.0
# 1997  613214.0             107566.0          0.0          0.0
# 1998  575653.0              91364.0          0.0          0.0
# 1999  544219.0              84704.0          0.0          0.0
# 2000  536645.0              79430.0          0.0          0.0
# 2001  522950.0              72416.0          0.0          0.0
# 2002  509343.0              69602.0          0.0          0.0
# 2003  493486.0              66644.0          0.0          0.0
# 2004  487316.0              60486.0          0.0          0.0
# 2005  480158.0              52689.0          0.0          0.0
# 2006  471589.0              48240.0          0.0          0.0
# 2007  461422.0              42690.0          0.0          0.0
# 2008  475596.0              37754.0          0.0          0.0
# 2009  468834.0              32872.0          0.0          0.0
# 2010  467610.0              30499.0          0.0          0.0
# 2011  462538.0              27876.0          0.0          0.0
# 2012  467623.0              26214.0          0.0          0.0
# 2013  451105.0              23580.0          0.0          0.0
# 2014  430707.0              23742.0          0.0          0.0
# 2015  405326.0              23296.0          0.0          0.0
# 2016  392516.0              22293.0          0.0          0.0
# 2017  377800.0              20925.0          0.0   38126713.0

# %% [markdown]
# According to the datafarm, we can know the status of seven types of crimes in New York State from 1990 to 2017.

# %%
# make the bar plot to see the value of the sum of index total  by matplotlib
year_df['Index Total'].plot(kind='bar')

# %% [markdown]
# From 1990 to1998, there were more than 1000000 crimes that occurred in New York State.In the recent years, the trend of crimes is decreasing.

# %%
#use seaborn to make the bar plot to see the value of the sum of index total
#Use reset_index to restore the Year index to become Year attribute

year_df.reset_index(drop = False, inplace=True)
sns.barplot(x='Year', y='Index Total', data=year_df)

# %% [markdown]
# From 1990 to1998, there were more than 1000000 crimes that occurred in New York State.

# %%
year_df = df.groupby('Year').sum()
year_df['Index Total'].describe()
# Out:
# count    2.800000e+01
# mean     9.145684e+05
# std      3.078958e+05
# min      5.517720e+05
# 25%      7.109315e+05
# 50%      7.881705e+05
# 75%      1.075846e+06
# max      1.571991e+06
# Name: Index Total, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017, the average numbers of all types of crimes are 1355 for each year in New York. To be surprised, there are Agencies report only 1 crime (minimum) and the maximun of crime's reports are 217786.

# %%
# get the max index total in the year_df

max_year_df = year_df[year_df['Index Total'] == year_df['Index Total'].max()]
max_year_df
# Out:
#       Index Total  Murder    Rape   Robbery  Aggravated Assault  Burglary  \
# Year
# 1991    1571991.0  2960.0  7270.0  126091.0            113311.0  295831.0
#
#        Larceny  Motor Vehicle Theft  Unnamed: 11  Unnamed: 12
# Year
# 1991  803873.0             222655.0          0.0          0.0

# %%
df['Index Total'].describe()
# Out:
# count     18900.000000
# mean       1354.916190
# std        7558.546118
# min           1.000000
# 25%          38.000000
# 50%         149.000000
# 75%         518.000000
# max      217786.000000
# Name: Index Total, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017, the average numbers of all types of crimes are 1355 for each year in New York. To be surprised, there are Agencies report only 1 crime (minimum) and the maximun of crime's reports are 217786.

# %% [markdown]
# The maximun of total index crimes was in 1991.

# %%
# 3. For the Index total attribute, we can make a plot to see the distribution of value

df['Index Total'].plot(kind='hist')

# %% [markdown]
#  The highest frequency of the crimes usually concentrats on the small range of crime index(0-50000). The frequency of crimes whose index is big is relatively low.

# %%
#use seaborn to make the histogram to see the value of the sum of index total

sns.distplot(df['Index Total'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of total crimes usually concentrate on 0 - 50000 of crime index.

# %%
# 4. For these seven attributes of crime, I can use figuer histogram to show their Frequencies of occurrence by matplotlib.
import matplotlib.pyplot as plt

fig,axes=plt.subplots(3,3,figsize=(15,10))

murder = axes[0,0].hist(df['Murder'])
axes[0,0].set_title('murder')

rape = axes[0,1].hist(df['Rape'])
axes[0,1].set_title('rape')

rape = axes[0,2].hist(df['Robbery'])
axes[0,2].set_title('robbery')

rape = axes[1,0].hist(df['Aggravated Assault'])
axes[1,0].set_title('aggravated assault')

rape = axes[1,1].hist(df['Burglary'])
axes[1,1].set_title('burglary')

rape = axes[1,2].hist(df['Larceny'])
axes[1,2].set_title('larceny')

rape = axes[2,0].hist(df['Motor Vehicle Theft'])
axes[2,0].set_title('motor vehicle theft')

fig.suptitle('This is a figure about the frequency of seven crimes', fontsize=16)
# Out:
# Text(0.5, 0.98, 'This is a figure about the frequency of seven crimes')

# %% [markdown]
# From the figure histogram above we can see that the highest frequency of the crimes usually concentrats on the small range of crime index. The frequency of crimes whose index is big is relatively low.

# %%
#get descriptive statistics for the Murder column by describe function
df['Murder'].describe()
# Out:
# count    18900.000000
# mean         2.168307
# std         20.438442
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        786.000000
# Name: Murder, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of murder crimes are 2 reports for each year in New York. In addition, the minimum are 0 and the maximum are 786.

# %%
#use seaborn to plot the histogram to see the frequency of Murder

sns.distplot(df['Murder'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of murder crimes usually concentrate on 0 - 150 of crime index.

# %%
#get descriptive statistics for the Rape column by describe function
df['Rape'].describe()
# Out:
# count    18900.000000
# mean         9.009788
# std         42.747372
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max       1159.000000
# Name: Rape, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of rape crimes are 9 reports for each year in New York. In addition, the minimum are 0 and the maximum are 1159 reports.

# %%
#Use seaborn to plot the histogram to see the frequency of Rape
sns.distplot(df['Rape'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of rape crimes usually concentrate on 0 - 200 of crime index.

# %%
#get descriptive statistics for the Robbery column by describe function
df['Robbery'].describe()
# Out:
# count    18900.000000
# mean        86.273968
# std        925.826745
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          5.000000
# max      36341.000000
# Name: Robbery, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of robbery crimes are 86 reports for each year in New York. In addition, the minimum are 0 and the maximum are 36341 reports.

# %%
#Use seaborn to plot the histogram to see the frequency of Robbery
sns.distplot(df['Robbery'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of robbery crimes usually concentrate on 0 - 5000 of crime index.

# %%
#get descriptive statistics for the Aggravated Assault column by describe function
df['Aggravated Assault'].describe()
# Out:
# count    18900.000000
# mean       111.502963
# std        826.585826
# min          0.000000
# 25%          1.000000
# 50%          7.000000
# 75%         28.000000
# max      24828.000000
# Name: Aggravated Assault, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of Aggravated Assault crimes are 112 reports for each year in New York. In addition, the minimum are 0 and the maximum are 24828 reports.

# %%
#Use seaborn to plot the histogram to see the frequency of Aggravated Assault
sns.distplot(df['Aggravated Assault'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of Aggravated Assault crimes usually concentrate on 0 - 5000 of crime index.

# %%
#get descriptive statistics for the Burglary column by describe function
df['Burglary'].describe()
# Out:
# count    18900.000000
# mean       220.482116
# std       1200.245040
# min          0.000000
# 25%          5.000000
# 50%         23.000000
# 75%         94.000000
# max      39041.000000
# Name: Burglary, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of Burglary crimes are 220 reports for each year in New York. In addition, the minimum are 0 and the maximum are 39041 reports.

# %%
#Use seaborn to plot the histogram to see the frequency of Burglary
sns.distplot(df['Burglary'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of Burglary crimes usually concentrate on 0 - 75000 of crime index.

# %%
#get descriptive statistics for the Larceny column by describe function
df['Larceny'].describe()
# Out:
# count     18900.000000
# mean        803.347354
# std        3810.211599
# min           0.000000
# 25%          25.000000
# 50%         107.000000
# 75%         354.250000
# max      122704.000000
# Name: Larceny, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of Larceny crimes are 803 reports for each year in New York. In addition, the minimum are 0 and the maximum are 122704 reports.

# %%
#Use seaborn to plot the histogram to see the frequency of Larceny
sns.distplot(df['Larceny'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of Larceny crimes usually concentrate on 0 - 20000 of crime index.

# %%
#get descriptive statistics for the Motor Vehicle Theft column by describe function
df['Motor Vehicle Theft'].describe()
# Out:
# count    18900.000000
# mean       122.131693
# std       1251.419956
# min          0.000000
# 25%          0.000000
# 50%          4.000000
# 75%         16.000000
# max      50300.000000
# Name: Motor Vehicle Theft, dtype: float64

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017,the average numbers of Motor Vehicle Theft crimes are 122 reports for each year in New York. In addition, the minimum are 0 and the maximum are 50300 reports.

# %%
#Use seaborn to plot the histogram to see the frequency of Motor Vehicle Theft
sns.distplot(df['Motor Vehicle Theft'], bins=5)

# %% [markdown]
# From the seaborn, we can see that the highest frequency of Motor Vehicle Theft crimes usually concentrate on 0 - 10000 of crime index.

# %%
# 1. For Index county and Total attributes, use bar chart to see the number of index total in different counties.

plt.bar(df['County'], df['Index Total'])
# Out:
# <BarContainer object of 19289 artists>

# %% [markdown]
# There are two counties had more than 200000 total index crimes from 1990 to 2017 in New York State.

# %%
# 2. For the Index total attribute, we can make a plot to see the distribution 

df['Index Total'].plot()

# %% [markdown]
# #From the chart we can see that the chart is fluctured, and the biggest index total is about 50000, and lots of data show zero crime which is great.

# %% [markdown]
# # Inference
# 1. use the groupby and count function get the accumulate index total for each county.
# 2. get the numbers of maximum and minimum accumulate index total for each county.
# 3. create the bar chart that reflect the numbers of index total crimes in each county by seaborn and matplotlib
# 4. analysis the bar chart

# %%
#At first, we need to groupby the county and sum the their index totals and create a new datafram to store the data
# print the result
county_df = df.groupby('County').sum()
county_df
# Out:
#                 Year  Index Total  Murder     Rape   Robbery  \
# County
# Albany        949316     693132.0   520.0   4516.0   25414.0
# Allegany      669340      51462.0    36.0    840.0     146.0
# Bronx          56098    1461565.0  6011.0  11290.0  212977.0
# Broome        657016     366954.0   300.0   3378.0    6114.0
# Wayne                    6066.0   24764.0    81520.0               3532.0
# Westchester             80820.0  172826.0   753048.0             131494.0
# Wyoming                  4738.0   12876.0    26876.0               1384.0
# Yates                    1274.0    5278.0    15962.0                410.0
#
#              Unnamed: 11  Unnamed: 12
# County
# Albany               0.0   38126713.0
# Allegany             0.0          0.0
# Bronx                0.0          0.0
# Broome               0.0          0.0
# Cattaraugus          0.0          0.0
# Cayuga               0.0          0.0
# Chautauqua           0.0          0.0
# Chemung              0.0          0.0
# Chenango             0.0          0.0
# Clinton              0.0          0.0
# Columbia             0.0          0.0
# Cortland             0.0          0.0
# Delaware             0.0          0.0
# Dutchess             0.0          0.0
# Erie                 0.0          0.0
# Essex                0.0          0.0
# Franklin             0.0          0.0
# Fulton               0.0          0.0
# Genesee              0.0          0.0
# Greene               0.0          0.0
# Hamilton             0.0          0.0
# Herkimer             0.0          0.0
# Jefferson            0.0          0.0
# Kings                0.0          0.0
# Lewis                0.0          0.0
# Livingston           0.0          0.0
# Madison              0.0          0.0
# Monroe               0.0          0.0
# Montgomery           0.0          0.0
# Nassau               0.0          0.0
# ...                  ...          ...
# Oneida               0.0          0.0
# Onondaga             0.0          0.0
# Ontario              0.0          0.0
# Orange               0.0          0.0
# Orleans              0.0          0.0
# Oswego               0.0          0.0
# Otsego               0.0          0.0
# Putnam               0.0          0.0
# Queens               0.0          0.0
# Rensselaer           0.0          0.0
# Richmond             0.0          0.0
# Rockland             0.0          0.0
# Saratoga             0.0          0.0
# Schenectady          0.0          0.0
# Schoharie            0.0          0.0
# Schuyler             0.0          0.0
# Seneca               0.0          0.0
# St Lawrence          0.0          0.0
# Steuben              0.0          0.0
# Suffolk              0.0          0.0
# Sullivan             0.0          0.0
# Tioga                0.0          0.0
# Tompkins             0.0          0.0
# Ulster               0.0          0.0
# Warren               0.0          0.0
# Washington           0.0          0.0
# Wayne                0.0          0.0
# Westchester          0.0          0.0
# Wyoming              0.0          0.0
# Yates                0.0          0.0
#
# [62 rows x 11 columns]

# %% [markdown]
# There are 62 county in New York State from 1990 to 2017.

# %%
# use the groupby function to get the accumulate index total for each county
# remove the unmeaningful column，Year','Murder','Rape','Robbery','Aggravated Assault','Burglary','Larceny','Motor Vehicle Theft by drop function
# print the result as df
county_df1 = df.groupby('County').sum()
county_df2 = county_df1.drop(columns = ['Year','Murder','Rape','Robbery','Aggravated Assault','Burglary','Larceny','Motor Vehicle Theft'])
# get descriptive statistics for the Index Total column by describe function
county_df2
# Out:
#              Index Total
# County
# Albany          693132.0
# Allegany         51462.0
# Bronx          1461565.0
# Broome          366954.0
# Cattaraugus     116828.0
# Cayuga          107000.0
# Chautauqua      231798.0
# Chemung         159984.0
# Chenango         62466.0
# Clinton          96440.0
# Columbia         75666.0
# Cortland         83948.0
# Delaware         49094.0
# Dutchess        359624.0
# Erie           2100360.0
# Essex            34280.0
# Franklin         55764.0
# Fulton           93316.0
# Genesee          87310.0
# Greene           56434.0
# Hamilton          4920.0
# Herkimer         76006.0
# Jefferson       144852.0
# Kings          2531196.0
# Lewis            19052.0
# Livingston       82192.0
# Madison          77942.0
# Monroe         1714978.0
# Montgomery       56670.0
# Nassau         1428036.0
# ...                  ...
# Oneida          382010.0
# Onondaga        902710.0
# Ontario         119658.0
# Orange          498930.0
# Orleans          50888.0
# Oswego          164110.0
# Otsego           63640.0
# Putnam           63460.0
# Queens         1980261.0
# Rensselaer      270138.0
# Richmond        278105.0
# Rockland        320626.0
# Saratoga        191428.0
# Schenectady     316700.0
# Schoharie        30228.0
# Schuyler         17208.0
# Seneca           38732.0
# St Lawrence     148788.0
# Steuben         122758.0
# Suffolk        2148122.0
# Sullivan        122514.0
# Tioga            38412.0
# Tompkins        170022.0
# Ulster          227236.0
# Warren          100694.0
# Washington       57682.0
# Wayne           118722.0
# Westchester    1214732.0
# Wyoming          46554.0
# Yates            23280.0
#
# [62 rows x 1 columns]

# %%
#use the max function find the maximum accumulate index total for each county from 1990 to 2017.
county_df2['Index Total'].max()
# Out:
# 2531196.0

# %%
#use the min function find the minimum accumulate index total for each county from 1990 to 2017.
county_df2['Index Total'].min()
# Out:
# 4920.0

# %% [markdown]
# According to the table, we can know that,from 1990 to 2017, the average numbers of all types of crimes are 1355 for each year in New York. To be surprised, there are Agencies report only 1 crime (minimum) and the maximun of crime's reports are 217786.

# %%
#Plot the bar chart to see the value of the sum of index total by different county

county_df['Index Total'].plot(kind='bar')

# %% [markdown]
# There are five counties reports more than 2,000,000 crimes during 1990 to 2017.

# %%
# Use reset_index to restore the County index to become County attribute
#use seaborn to make the bar plot to see the value of the sum of index total

county_df.reset_index(drop=False, inplace=True)
sns.barplot(x='County', y='Index Total', data = county_df)

# %% [markdown]
# There are five counties reports more than 2,000,000 crimes during 1990 to 2017

# %%
# Get the max index total in the county_df to see which county is the most dangerous
# print the result
max_county_df = county_df[county_df['Index Total'] == county_df['Index Total'].max()]
max_county_df
# Out:
#    County   Year  Index Total  Murder     Rape   Robbery  Aggravated Assault  \
# 23  Kings  56098    2531196.0  8423.0  17391.0  379651.0            384780.0
#
#     Burglary    Larceny  Motor Vehicle Theft  Unnamed: 11  Unnamed: 12
# 23  380350.0  1006844.0             353757.0          0.0          0.0

# %% [markdown]
# The county Kings is the mast dangerous areas with the highest index total, 2531196. Other than that,among 62 counties of New York State, there are also 4 more areas are dangerous than other place, from 1990 to 2017.

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. As time pass, we can see the total criminal trend is going down. This reflect that the crime control and safety situation of each county is becoming better.
# 2. The county Kings is the mast dangerous areas with the highest index total (2531196) in New York State from 1990 to 2017.
# 3. From 1990 to 2017, the total index of crime data ranking has a big different from the minimum, 25%,50% and 75% number level is all under or equal 518 cases, while the max crime index is 217786, which has a big difference from the most index numbers. This is quite unnormal so we can guess there might be data missing for this set of number. Or we can conclude that maybe the median index, which is the 50% ranking index number here can be better to represent the overall standard of the crime numbers.

# %% [markdown]
# # Reference

# %% [markdown]
# https://www.kaggle.com/questions-and-answers/55356

# %% [markdown]
# https://www.kaggle.com/new-york-state/new-york-state-index-crimes

# %% [markdown]
# https://towardsdatascience.com/pandas-tips-and-tricks-33bcc8a40bb9
